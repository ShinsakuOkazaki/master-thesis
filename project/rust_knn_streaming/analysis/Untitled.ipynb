# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dfs = {}
for m in ['deep', 'arc']:
    for s in ['s1', 's2']:       
        with open("ganglia-b3-" + s + "-" + m + ".csv", "r") as f:
            file = [s.strip().split(",") for s in f.readlines()]
            df = pd.DataFrame(file)
            header = df.iloc[0]

            df = df[1:]
            df.columns = header
            type_map = {"Timestamp": "datetime64[ns]"}
            for h in header[1:]:
                type_map[h] = "float"
            df = df.astype(type_map)
            dfs[m + "-" + s] = df

# %%
dfs["deep-s1"]
# Out:
# 0    Timestamp         Use\g  Share\g       Cache\g    Buffer\g  Swap\g  \
# 1   1970-01-01  2.535506e+08      0.0  2.854257e+08  24276992.0     0.0
# 2   1970-01-01  2.535506e+08      0.0  2.854257e+08  24276992.0     0.0
# 3   1970-01-01  2.514357e+08      0.0  2.854065e+08  24297472.0     0.0
# 4   1970-01-01  2.472059e+08      0.0  2.853683e+08  24338432.0     0.0
# 5   1970-01-01  2.472059e+08      0.0  2.853683e+08  24338432.0     0.0
# ..         ...           ...      ...           ...         ...     ...
# 236 1970-01-01  2.557542e+08      0.0  7.711826e+08  31457280.0     0.0
# 237 1970-01-01  2.557542e+08      0.0  7.711826e+08  31457280.0     0.0
# 238 1970-01-01  2.557542e+08      0.0  7.711826e+08  31457280.0     0.0
# 239 1970-01-01  2.557542e+08      0.0  7.711826e+08  31457280.0     0.0
# 240 1970-01-01           NaN      NaN           NaN         NaN     NaN
#
# 0         Total\g
# 1    3.162830e+10
# 2    3.162830e+10
# 3    3.162830e+10
# 4    3.162830e+10
# ...

# %%
fig, ax = plt.subplots(figsize = (20, 10))
ax.plot(dfs["deep-s1"]['Use\\g'][10:100])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20, 10))
ax.plot(dfs["arc-s1"]['Use\\g'][160:])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20, 10))
ax.plot(dfs["deep-s2"]['Use\\g'][140:])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20, 10))
ax.plot(dfs["arc-s2"]['Use\\g'][150:])
plt.show()

# %%
dfs["deep-s1"]['Use\\g'][10:100].max()
# Out:
# 25668239360.0

# %%
dfs["arc-s1"]['Use\\g'][160:].max()
# Out:
# 25931030528.0

# %%
dfs["deep-s2"]['Use\\g'][140:].max()
# Out:
# 16259383296.0

# %%
dfs["arc-s2"]['Use\\g'][150:].max()
# Out:
# 10081435648.0

# %%
fig, ax = plt.subplots(figsize = (20, 10))
ax.plot(dfs["deep-s1"]['Cache\\g'][20:100])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20, 10))
ax.plot(dfs["arc-s1"]['Cache\\g'][160:])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20, 10))
ax.plot(dfs["arc-s2"]['Cache\\g'][170:])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20, 10))
ax.plot(dfs["deep-s2"]['Cache\\g'][140:])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20, 10))
ax.plot(dfs["arc-s2"]['Cache\\g'][150:])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20, 10))
ax.plot(dfs["deep-s2"]['Cache\\g'])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20, 10))
ax.plot(dfs["arc-s2"]['Cache\\g'])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20, 10))
ax.plot(dfs["deep-s2"]['Cache\\g'])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20, 10))
ax.plot(dfs["deep-s1"]['Cache\\g'])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20, 10))
ax.plot(dfs["arc-s1"]['Cache\\g'])
plt.show()
